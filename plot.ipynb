# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_accuracy_vs_rounds_from_files(file_paths, title):
    plt.figure(figsize=(10, 6)) 

    colors = ['r', 'g', 'b', 'orange']

    for idx, file_path in enumerate(file_paths):
        with open(file_path, 'r') as file:
            data = [float(line.strip()) for line in file]

        rounds = list(range(1, len(data) + 1)) 

        plt.plot(rounds, data, linestyle='-', color=colors[idx % len(colors)], label=f'{file_paths[file_path]}')

    plt.title(title)
    plt.xlabel('Rounds')
    plt.ylabel('Accuracy')
    plt.yticks(np.arange(0, 1.0, 0.1))
    plt.legend(loc='best') 
    plt.grid(True)

    plt.show()

# %%
file_paths = {
    'testes/0infected': 'Sem ataque',
    'testes/noProtectionCoordenate/10infected': "10% infectado",  
    'testes/noProtectionCoordenate/20infected': "20% infectado",
    'testes/noProtectionCoordenate/30infected': "30% infectado"  
}

plot_accuracy_vs_rounds_from_files(file_paths, 'Ataque coordenado em sistema desprotegido')

# %%
file_paths = {
    'testes/0infected': 'Sem ataque',
    'testes/noProtectionNotCoordenate/10infected': "10% infectado",  
    'testes/noProtectionNotCoordenate/20infected': "20% infectado",
    'testes/noProtectionNotCoordenate/30infected': "30% infectado",
}

plot_accuracy_vs_rounds_from_files(file_paths, 'Ataque não coordenado em sistema desprotegido')

# %%
file_paths = {
    'testes/0infected': 'Sem ataque',
    'testes/confiabilityBased/coordenate/10infectedAcc': "10% infectado",  
    'testes/confiabilityBased/coordenate/20infectedAcc': "20% infectado",
    'testes/confiabilityBased/coordenate/30infectedAcc': "30% infectado",
}

plot_accuracy_vs_rounds_from_files(file_paths, 'Ataque coordenado em sistema protegido - K = 4')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 8
#       1 file_paths = {
#       2     'testes/0infected': 'Sem ataque',
#       3     'testes/confiabilityBased/coordenate/10infectedAcc': "10% infectado",
#       4     'testes/confiabilityBased/coordenate/20infectedAcc': "20% infectado",
#       5     'testes/confiabilityBased/coordenate/30infectedAcc': "30% infectado",
#       6 }
# ----> 8 plot_accuracy_vs_rounds_from_files(file_paths, 'Ataque coordenado em sistema protegido - K = 4')
#
# Cell In[5], line 10, in plot_accuracy_vs_rounds_from_files(file_paths, title)
#       7 colors = ['r', 'g', 'b', 'orange']
#       9 for idx, file_path in enumerate(file_paths):
# ---> 10     with open(file_path, 'r') as file:
#      11         data = [float(line.strip()) for line in file]
#      13     rounds = list(range(1, len(data) + 1))
#
# ...

# %%
file_paths = {
    'testes/0infected': 'Sem ataque',
    'testes/confiabilityBased/notCoordenate/10infectedAcc': "10% infectado",  
    'testes/confiabilityBased/notCoordenate/20infectedAcc': "20% infectado",
    'testes/confiabilityBased/notCoordenate/30infectedAcc': "30% infectado",
}

plot_accuracy_vs_rounds_from_files(file_paths, 'Ataque não coordenado em sistema protegido - K = 4')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 8
#       1 file_paths = {
#       2     'testes/0infected': 'Sem ataque',
#       3     'testes/confiabilityBased/notCoordenate/10infectedAcc': "10% infectado",
#       4     'testes/confiabilityBased/notCoordenate/20infectedAcc': "20% infectado",
#       5     'testes/confiabilityBased/notCoordenate/30infectedAcc': "30% infectado",
#       6 }
# ----> 8 plot_accuracy_vs_rounds_from_files(file_paths, 'Ataque não coordenado em sistema protegido - K = 4')
#
# Cell In[5], line 10, in plot_accuracy_vs_rounds_from_files(file_paths, title)
#       7 colors = ['r', 'g', 'b', 'orange']
#       9 for idx, file_path in enumerate(file_paths):
# ---> 10     with open(file_path, 'r') as file:
#      11         data = [float(line.strip()) for line in file]
#      13     rounds = list(range(1, len(data) + 1))
#
# ...

# %%
file_paths = {
    'testes/0infected': 'Sem ataque',
    'testes/confiabilityBased/notCoordenate/30infectedAccK2': "30% infectado",
}

plot_accuracy_vs_rounds_from_files(file_paths, 'Ataque não coordenado em sistema protegido - K = 2')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 6
#       1 file_paths = {
#       2     'testes/0infected': 'Sem ataque',
#       3     'testes/confiabilityBased/notCoordenate/30infectedAccK2': "30% infectado",
#       4 }
# ----> 6 plot_accuracy_vs_rounds_from_files(file_paths, 'Ataque não coordenado em sistema protegido - K = 2')
#
# Cell In[5], line 10, in plot_accuracy_vs_rounds_from_files(file_paths, title)
#       7 colors = ['r', 'g', 'b', 'orange']
#       9 for idx, file_path in enumerate(file_paths):
# ---> 10     with open(file_path, 'r') as file:
#      11         data = [float(line.strip()) for line in file]
#      13     rounds = list(range(1, len(data) + 1))
#
# File ~/.local/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
# ...

# %%
file_paths = {
    'testes/0infected': 'No attackers',
    'dif': "30% infected",
}

plot_accuracy_vs_rounds_from_files(file_paths, 'Ataque não coordenado em sistema protegido - K = 4')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 6
#       1 file_paths = {
#       2     'testes/0infected': 'No attackers',
#       3     'dif': "30% infected",
#       4 }
# ----> 6 plot_accuracy_vs_rounds_from_files(file_paths, 'Ataque não coordenado em sistema protegido - K = 4')
#
# Cell In[5], line 10, in plot_accuracy_vs_rounds_from_files(file_paths, title)
#       7 colors = ['r', 'g', 'b', 'orange']
#       9 for idx, file_path in enumerate(file_paths):
# ---> 10     with open(file_path, 'r') as file:
#      11         data = [float(line.strip()) for line in file]
#      13     rounds = list(range(1, len(data) + 1))
#
# File ~/.local/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
# ...

# %%
file_paths = {
    'testes/nonIdd/notInfecAcc': 'Sem ataque',
    'testes/nonIdd/coord/10InfecAcc': "10% infectado",  
    'testes/nonIdd/coord/20InfecAcc': "20% infectado",
    'testes/nonIdd/coord/30InfecAcc': "30% infectado",
}

plot_accuracy_vs_rounds_from_files(file_paths, 'Ataque coordenado em sistema protegido - K = 4 - NonIid')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 8
#       1 file_paths = {
#       2     'testes/nonIdd/notInfecAcc': 'Sem ataque',
#       3     'testes/nonIdd/coord/10InfecAcc': "10% infectado",
#       4     'testes/nonIdd/coord/20InfecAcc': "20% infectado",
#       5     'testes/nonIdd/coord/30InfecAcc': "30% infectado",
#       6 }
# ----> 8 plot_accuracy_vs_rounds_from_files(file_paths, 'Ataque coordenado em sistema protegido - K = 4 - NonIid')
#
# Cell In[5], line 10, in plot_accuracy_vs_rounds_from_files(file_paths, title)
#       7 colors = ['r', 'g', 'b', 'orange']
#       9 for idx, file_path in enumerate(file_paths):
# ---> 10     with open(file_path, 'r') as file:
#      11         data = [float(line.strip()) for line in file]
#      13     rounds = list(range(1, len(data) + 1))
#
# ...

# %%
file_paths = {
    'testes/nonIdd/notInfecAcc': 'Sem ataque',
    'testes/nonIdd/notCoord/10InfecAcc': "10% infectado",  
    'testes/nonIdd/notCoord/20InfecAcc': "20% infectado",
    'testes/nonIdd/notCoord/30InfecAcc': "30% infectado",
}

plot_accuracy_vs_rounds_from_files(file_paths, 'Ataque não coordenado em sistema protegido - K = 4 - NonIid')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 8
#       1 file_paths = {
#       2     'testes/nonIdd/notInfecAcc': 'Sem ataque',
#       3     'testes/nonIdd/notCoord/10InfecAcc': "10% infectado",
#       4     'testes/nonIdd/notCoord/20InfecAcc': "20% infectado",
#       5     'testes/nonIdd/notCoord/30InfecAcc': "30% infectado",
#       6 }
# ----> 8 plot_accuracy_vs_rounds_from_files(file_paths, 'Ataque não coordenado em sistema protegido - K = 4 - NonIid')
#
# Cell In[5], line 10, in plot_accuracy_vs_rounds_from_files(file_paths, title)
#       7 colors = ['r', 'g', 'b', 'orange']
#       9 for idx, file_path in enumerate(file_paths):
# ---> 10     with open(file_path, 'r') as file:
#      11         data = [float(line.strip()) for line in file]
#      13     rounds = list(range(1, len(data) + 1))
#
# ...

# %%
file_paths = {
    'testes/cifar/0infected': 'Sem ataque',
    'testes/cifar/coord/10infected': "10% infectado",  
    'testes/cifar/coord/20infected': "20% infectado",
    'testes/cifar/coord/30infected': "30% infectado",
}

plot_accuracy_vs_rounds_from_files(file_paths, 'Ataque coordenado em sistema protegido - K = 4 - CIFAR10')

# %%
file_paths = {
    'testes/cifar/0infected': 'Sem ataque',
    'testes/cifar/notCoord/10infected': "10% infectado",  
    'testes/cifar/notCoord/20infected': "20% infectado",
    'testes/cifar/notCoord/30infected': "30% infectado",
}

plot_accuracy_vs_rounds_from_files(file_paths, 'Ataque não coordenado em sistema protegido - K = 4 - CIFAR10')

# %%
file_paths = {
    'testes/cifar/nonIdd/0infected': 'Sem ataque',
    'testes/cifar/nonIdd/notCoord/10infected': "10% infectado",  
    'testes/cifar/nonIdd/notCoord/20infected': "20% infectado",
    # 'testes/cifar/notCoord/30infected': "30% infectado",
}

plot_accuracy_vs_rounds_from_files(file_paths, 'Ataque não coordenado em sistema protegido - K = 4 - CIFAR10 - Distribuição NonIid')

# %%
file_paths = {
    'testes/cifar/nonIdd/0infected': 'Sem ataque',
    'testes/cifar/nonIdd/coord/10infected': "10% infectado",  
    'testes/cifar/nonIdd/coord/20infected': "20% infectado",
    # 'testes/cifar/notCoord/30infected': "30% infectado",
}

plot_accuracy_vs_rounds_from_files(file_paths, 'Ataque coordenado em sistema protegido - K = 4 - CIFAR10 - Distribuição NonIid')
